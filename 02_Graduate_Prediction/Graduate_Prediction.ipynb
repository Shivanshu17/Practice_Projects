# %% [markdown]
# This file is created to implement the raw Linear Regression model that I created and compare the results with the sklearn implementation of Linear Regression.
# I will try my code out on the regression problem of predicting the probability that a student will get an admission in graduate program.
# Lets get Started!!

# %% [markdown]
# ** The questions I will be answering for myself are as follows: **
# * How to handle categorical/nominal/ordinal values in regression problems?
# * When do we need to standardize and normalize the data?
# * How to know that we are gonna need to add regularization in our model? (I haven't coded regularization part in my code)

# %%
import pandas as pd
import numpy as np
import sys
import os
import sklearn.preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import sklearn.linear_model
import sklearn.metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Here we import the code I wrote from scatch
import Linear_Regression as lr

# %%
df = pd.read_csv('Admission_Predict_Ver1.1.csv')
display(df.head())
display(df.sample())
#display(df.info)
display(df.describe())
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 176         177        329          119                  4  4.5   4.5  9.16
#
#      Research  Chance of Admit
# 176         1               0.9
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# 25%      3.00000    8.127500    0.000000           0.63000
# 50%      3.50000    8.560000    1.000000           0.72000
# 75%      4.00000    9.040000    1.000000           0.82000
# max      5.00000    9.920000    1.000000           0.97000

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# We are first gonna plot the GRE score range and TOEFL score range, and it seems like people generally score more than 295 with a majority of people scoring between 310 and 325. The data does not seem to have any outliers in these two categories.

# %%
sns.set()
_ = plt.hist(df['GRE Score'], bins = 20, edgecolor = 'white')
_ = plt.xlabel('GRE Score')
_ = plt.ylabel("Number of Students")
plt.show()

# %%
_ = plt.hist(df['TOEFL Score'], bins = 20, edgecolor = 'white')
_ = plt.xlabel('TOEFL Score')
_ = plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# Well, lets try to find out if there are any outliers in SOP, LOR, and CGPA columns of the given dataframe. We will use a box plot for this purpose. This will also help us get a feel of the range of variance in these three columns of the dataframe.
# ** It seems like there are no outliers in this dataset.**

# %%
df.loc[:, ['SOP', 'LOR ', 'CGPA']].boxplot()

# %% [markdown]
# Next up, we want to see if any of the variables are highly correlated with each other, and which variables are most correlated with the objective feature - Chance of Admit. For this, we will plot the heatmap of the data and draw inference from that.

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot = True)

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# The heatmap above helps us draw a few simple intuitions about the data.
# * Chance of Admit is very highly correlated to CGPA, and shows quite a bit of correlation with GRE and TOEFL scores. This seems justified
# * The odd fish among these features is the 'Research' feature. It seems like research has the least amount of correlation with Chance of Admit, and also has really bad correlation (comparatively) to other features like LOR, and CGPA. This is odd, but reasonable. People focussed on research generally are outliers that like to work independently (hence low LOR ratings), and don't like to focus too much on the "frivilous" activities like (CGPA, and SOP)

# %% [markdown]
# ### Data Preparation
# Here we will do the following:
# * Answer the first two questions asked at the start of this notebook.
# * Extract the target variable and split the data into training and test sets.

# %% [markdown]
# ##### Q1. How to handle categorical and nominal/ordinal data in case of linear regression problems
#
# Ans: For categorical data, use one hot vector encoding to turn the data into numerical form (if it isn't in that form). You don't have to do anything for Nominal and Ordinal data, the LR model inherently detects patterns of ordinality implicitly, and no additional effort needs to be directed at that problem.

# %% [markdown]
# ##### Q2. When do we need to standardize/normalize the data?
#
# Ans: Well, sklearn.linear_model has parameters "fit_intercept" and "normalize" for centering the data, and normalizing it, respectively. We can use a scaler of our choice form sklearn.preprocessing library. I have used standard_scaler and min_max_scaler before, and I will probably have to use one of them for my own code, because I haven't included normalization in my code.

# %%
df_train_y = df.loc[:449, ['Chance of Admit ']]
df_X = df.copy()
df_X = df_X.drop(['Chance of Admit '], axis = 1)
df_train_X = df_X.iloc[:-50, :]
df_test_y = df.loc[450:, ['Chance of Admit ']]
df_test_X = df_X.iloc[-50:, :]
df_train = df.loc[:449, :]

display(df_train_X.describe())
display(df_test_X.describe())
display(df_train_y.describe())
display(df_test_y.describe())
display(df_train.describe())
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  450.000000  450.000000   450.000000         450.000000  450.000000
# mean   225.500000  316.726667   107.348889           3.080000    3.373333
# std    130.048068   11.304982     6.070159           1.151275    1.004201
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    113.250000  309.000000   103.000000           2.000000    2.500000
# 50%    225.500000  317.000000   107.000000           3.000000    3.500000
# 75%    337.750000  325.000000   112.000000           4.000000    4.000000
# max    450.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research
# count  450.000000  450.000000  450.000000
# mean     3.477778    8.585178    0.555556
# std      0.915443    0.605303    0.497457
# min      1.000000    6.800000    0.000000
# 25%      3.000000    8.132500    0.000000
# 50%      3.500000    8.570000    1.000000
# 75%      4.000000    9.060000    1.000000
# max      5.000000    9.920000    1.000000
#        Serial No.   GRE Score  TOEFL Score  University Rating        SOP  \
# count    50.00000   50.000000    50.000000          50.000000  50.000000
# mean    475.50000  314.180000   105.780000           3.420000   3.380000
# std      14.57738   11.054023     6.065257           1.031939   0.872248
# min     451.00000  295.000000    95.000000           1.000000   1.500000
# 25%     463.25000  304.250000   101.250000           3.000000   2.625000
# 50%     475.50000  315.000000   105.000000           4.000000   3.500000
# 75%     487.75000  323.000000   110.000000           4.000000   4.000000
# max     500.00000  337.000000   120.000000           5.000000   5.000000
#
#             LOR        CGPA   Research
# count  50.000000  50.000000  50.000000
# mean    3.540000   8.497800   0.600000
# std     1.019404   0.600684   0.494872
# min     1.500000   7.210000   0.000000
# 25%     2.625000   8.030000   0.000000
# 50%     3.500000   8.465000   1.000000
# 75%     4.500000   8.940000   1.000000
# max     5.000000   9.870000   1.000000
#        Chance of Admit
# count        450.000000
# mean           0.722311
# std            0.142438
# min            0.340000
# 25%            0.630000
# 50%            0.725000
# 75%            0.827500
# max            0.970000
#        Chance of Admit
# count         50.000000
# mean           0.716600
# std            0.130096
# min            0.370000
# 25%            0.642500
# 50%            0.710000
# 75%            0.807500
# max            0.960000
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  450.000000  450.000000   450.000000         450.000000  450.000000
# mean   225.500000  316.726667   107.348889           3.080000    3.373333
# std    130.048068   11.304982     6.070159           1.151275    1.004201
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    113.250000  309.000000   103.000000           2.000000    2.500000
# 50%    225.500000  317.000000   107.000000           3.000000    3.500000
# 75%    337.750000  325.000000   112.000000           4.000000    4.000000
# max    450.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  450.000000  450.000000  450.000000        450.000000
# mean     3.477778    8.585178    0.555556          0.722311
# std      0.915443    0.605303    0.497457          0.142438
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.132500    0.000000          0.630000
# 50%      3.500000    8.570000    1.000000          0.725000
# 75%      4.000000    9.060000    1.000000          0.827500
# max      5.000000    9.920000    1.000000          0.970000

# %% [markdown]
# ### Model Preparation and Training
# Here we are gonna do the following things:
# 1. We are gonna train the sklearn.linear_model.LinearRegression model, with (& without) fit_intercept set to true, and normalize set to True.
# 2. We are gonna train the dataset on our own Linear Regression model, with (& without) using standard scaler on the data before hand.

# %% [markdown]
# ##### 1. Using the Linear Regression model of the sklearn library

# %%
sk_model = sklearn.linear_model.LinearRegression(fit_intercept = True, normalize = True).fit(df_train_X, df_train_y)
predicted_values = sk_model.predict(df_test_X)
error_metric = sklearn.metrics.mean_squared_error(df_test_y, predicted_values)

# %%
predicted_df = pd.DataFrame(predicted_values, columns = ['Chance of Admit '])
predicted_df.index = df_test_y.index

# %%
plt.figure(figsize = (20,7))
plt.plot(predicted_df['Chance of Admit '], color = 'red', marker = '.', label = "Predicted Values")
plt.plot(df_test_y['Chance of Admit '], color = 'blue', marker = '.', label = "Actual Values")
plt.title("Plot with Normalization; Mean Squared Error is {error:f}".format(error = error_metric))
plt.xlabel("Test Set Index")
plt.ylabel("Test Set Values")
plt.legend(loc = 'lower right')
plt.show()

# %%
sk_model_2 = sklearn.linear_model.LinearRegression().fit(df_train_X, df_train_y)
predicted_values_2 = sk_model_2.predict(df_test_X)
error_metric_2 = sklearn.metrics.mean_squared_error(df_test_y, predicted_values_2)

# %%
predicted_df_2 = pd.DataFrame(predicted_values_2, columns = ['Chance of Admit '])
predicted_df_2.index = df_test_y.index

# %%
plt.figure(figsize = (20,7))
plt.plot(predicted_df_2['Chance of Admit '], color = 'red', marker = '.', label = "Predicted Values")
plt.plot(df_test_y['Chance of Admit '], color = 'blue', marker = '.', label = "Actual Values")
plt.title("Plot without Normalization; Mean Squared Error is {error:f}".format(error = error_metric_2))
plt.xlabel("Test Set Index")
plt.ylabel("Test Set Values")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ##### Using My own code for Linear Regression

# %%
def standard_scaler(X_train, X_test):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    #display(X_train_scaled)
    #display(X_test_scaled.shape)
    return X_train_scaled, X_test_scaled

def minmax_scaler(X_train, X_test):
    minmaxscaler = MinMaxScaler()
    X_train_scaled = minmaxscaler.fit_transform(X_train)
    X_test_scaled = minmaxscaler.transform(X_test)
    #display(X_train_minmax_scaled)
    #display(X_test_minmax_scaled.shape)
    return X_train_scaled, X_test_scaled

# %%
lr_df_train_scaled, lr_df_test_scaled = minmax_scaler(df_train_X, df_test_X)
columns_df_train_X = list(df_train_X.columns)
columns_df_test_X = list(df_test_X.columns)
lr_df_train_scaled = pd.DataFrame(lr_df_train_scaled, columns = columns_df_train_X)
lr_df_test_scaled = pd.DataFrame(lr_df_test_scaled, columns = columns_df_test_X)
df_train_scaled = pd.concat([lr_df_train_scaled, df_train.iloc[:, -1]], axis = 1)
df_train_scaled = df_train_scaled.drop(['Serial No.'], axis = 1)
lr_df_test_scaled = lr_df_test_scaled.drop(['Serial No.'], axis = 1)

# %%
df_train_scaled.head()
# Out:
#    GRE Score  TOEFL Score  University Rating    SOP   LOR       CGPA  \
# 0       0.94     0.928571               0.75  0.875  0.875  0.913462
# 1       0.68     0.535714               0.75  0.750  0.875  0.663462
# 2       0.52     0.428571               0.50  0.500  0.625  0.384615
# 3       0.64     0.642857               0.50  0.625  0.375  0.599359
# 4       0.48     0.392857               0.25  0.250  0.500  0.451923
#
#    Research  Chance of Admit
# 0       1.0              0.92
# 1       1.0              0.76
# 2       1.0              0.72
# 3       1.0              0.80
# 4       0.0              0.65

# %%
lr_df_test_scaled.head()
# Out:
#    GRE Score  TOEFL Score  University Rating    SOP   LOR       CGPA  Research
# 0       0.60     0.714286               0.75  0.500  0.875  0.660256       1.0
# 1       0.68     0.750000               0.75  0.875  0.875  0.785256       1.0
# 2       0.76     0.857143               0.75  1.000  0.625  0.897436       1.0
# 3       0.58     0.392857               0.50  0.375  0.750  0.628205       1.0
# 4       0.40     0.464286               0.25  0.500  0.625  0.387821       0.0

# %%
# Here we import the code I wrote from scatch
import Linear_Regression as lr

# %%
model_lr_1 = lr.LinearRegressionClass(df_train_scaled, lr = 0.001)
model_lr_1.fit()
#print(type(model_lr_1))
#print(model_lr_1)
predicted_values = model_lr_1.predict(lr_df_test_scaled)

print(predicted_values)
# Out:
# [0.82523595 0.9457049  0.97928755 0.73345307 0.5771833  0.36952714
#  0.3580036  0.26914947 0.64061534 0.90016417 0.75308408 0.39009099
#  0.45244083 0.47760369 0.27456977 0.57263224 0.70899895 0.75011817
#  0.8789699  0.8557371  0.84275855 0.57684961 1.01323098 0.62068568
#  0.40599863 0.39531711 0.42260762 0.43912401 0.73436586 0.83256758
#  0.79962745 0.57314847 0.69889655 0.424504   0.50378095 0.60369135
#  0.54585769 0.90498604 0.77508419 0.74353484 0.64641434 0.39716994
#  0.44303091 0.36409632 0.43817494 0.82262191 1.15126747 1.07679926
#  0.72377726 0.92480664]

# %%
print(model_lr_1.get_params())
# Out:
# The Parameters are :  [ 0.15165371  0.16881238 -0.12610489  0.05776465  0.30492718  0.64516714
#  -0.01342722]
# [ 0.15165371  0.16881238 -0.12610489  0.05776465  0.30492718  0.64516714
#  -0.01342722]

# %%
error_metric_3 = sklearn.metrics.mean_squared_error(df_test_y, predicted_values)
print(error_metric_3)
# Out:
# 0.018834666893072696

# %% [markdown]
# Woah!! That's a really bad value... (This refers to the first score I got : e^160 something) A really really bad score. I have to do the following:
# 1. Go through the code and try to detect if there is anything wrong.
# 2. If I can't detect anything this way, then create a very simple linear regression problem (of 1 parameter) and try to predict that. Try to understand using this example, what's going wrong.
#
# This final value is quite decent.

# %%
predicted_df_3 = pd.DataFrame(predicted_values, columns = ['Chance of Admit '])
predicted_df_3.index = df_test_y.index

# %%
sns.set()
plt.figure(figsize = (20,7))
plt.plot(predicted_df_3['Chance of Admit '], color = 'red', marker = '.', label = "Predicted Values")
plt.plot(df_test_y['Chance of Admit '], color = 'blue', marker = '.', label = "Actual Values")
plt.title("Plot without Normalization; Mean Squared Error is {error:f}".format(error = error_metric_3))
plt.xlabel("Test Set Index")
plt.ylabel("Test Set Values")
plt.legend(loc = 'lower right')
plt.show()

# %%
model_lr_2 = lr.LinearRegressionClass(df_train_scaled, lr = 0.001, epoch = 1500, optimization = 2)
model_lr_2.fit()
#print(type(model_lr_1))
#print(model_lr_1)
predicted_values_10 = model_lr_2.predict(lr_df_test_scaled)

print(predicted_values_10)

error_metric_4 = sklearn.metrics.mean_squared_error(df_test_y, predicted_values_10)
# Out:
# [0.82397406 0.94604305 0.98687017 0.73766272 0.56738931 0.364886
#  0.36776692 0.27735053 0.65025696 0.90418431 0.74682292 0.40517333
#  0.44571043 0.46979276 0.26353157 0.57348793 0.71366656 0.74879865
#  0.87053712 0.85704938 0.85251369 0.56957527 1.01719133 0.60642576
#  0.40366488 0.39667417 0.43053818 0.43979955 0.7253822  0.82711677
#  0.80593522 0.56883559 0.69208232 0.41482156 0.48634081 0.60790107
#  0.54329973 0.90066959 0.76747002 0.74630641 0.64292461 0.39740693
#  0.43824846 0.38612977 0.46318648 0.81192871 1.14958391 1.07441546
#  0.71412239 0.91318387]

# %%
predicted_df_4 = pd.DataFrame(predicted_values_10, columns = ['Chance of Admit '])
predicted_df_4.index = df_test_y.index

# %%
plt.figure(figsize = (20,7))
plt.plot(predicted_df_4['Chance of Admit '], color = 'red', marker = '.', label = "Predicted Values")
plt.plot(df_test_y['Chance of Admit '], color = 'blue', marker = '.', label = "Actual Values")
plt.title("Plot without Normalization; Mean Squared Error is {error:f}".format(error = error_metric_4))
plt.xlabel("Test Set Index")
plt.ylabel("Test Set Values")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### Evaluating the results
